# %% [markdown]
# # Beer Classification - using only Overall Rating - 3 beer review

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://query.data.world/s/5wrkcltf0rqhyu2ahlayldrfg")
df.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# 2          Foreign / Export Stout            3.0           3.0
# 3                 German Pilsener            2.5           3.0
# 4  American Double / Imperial IPA            4.0           4.5
#
#                 beer_name  beer_abv  beer_beerid
# 0            Sausa Weizen       5.0        47986
# 1                Red Moon       6.2        48213
# 2  Black Horse Black Beer       6.5        48215
# 3              Sausa Pils       5.0        47969
# 4           Cauldron DIPA       7.7        64883

# %%
cleandata = df.loc[:,["review_overall","review_aroma","review_appearance","review_profilename", "review_palate","review_taste",
                      "beer_name","beer_abv"]]
cleandata.head()
# Out:
#    review_overall  review_aroma  review_appearance review_profilename  \
# 0             1.5           2.0                2.5            stcules
# 1             3.0           2.5                3.0            stcules
# 2             3.0           2.5                3.0            stcules
# 3             3.0           3.0                3.5            stcules
# 4             4.0           4.5                4.0     johnmichaelsen
#
#    review_palate  review_taste               beer_name  beer_abv
# 0            1.5           1.5            Sausa Weizen       5.0
# 1            3.0           3.0                Red Moon       6.2
# 2            3.0           3.0  Black Horse Black Beer       6.5
# 3            2.5           3.0              Sausa Pils       5.0
# 4            4.0           4.5           Cauldron DIPA       7.7

# %%
beer1 = "Budweiser"
overall1 = 1
appearance1 = 3
aroma1 = 2
palate1 = 1
taste1 = 3
beer2 = "Weihenstephaner Hefeweissbier"
overall2 = 5
appearance2 = 5
aroma2 = 4
palate2 = 5
taste2 = 5
beer3 = "Trappistes Rochefort 6"
overall3 = 3
appearance3 = 4
aroma3 = 4
palate3 = 5
taste3 = 5

# %%
first = cleandata[(cleandata.beer_name == beer1) & (cleandata.review_overall == overall1)]

first.head()
# Out:
#          review_overall  review_aroma  review_appearance review_profilename  \
# 1308962             1.0           1.5                2.0      DarkBeerRuler
# 1308971             1.0           2.0                3.5       beachbum1975
# 1308991             1.0           1.5                1.5      HomelessShoes
# 1309009             1.0           1.5                3.0            xduderx
# 1309011             1.0           1.5                1.5    GratefulBeerGuy
#
#          review_palate  review_taste  beer_name  beer_abv
# 1308962            2.0           1.0  Budweiser       5.0
# 1308971            1.5           2.0  Budweiser       5.0
# 1308991            1.5           1.0  Budweiser       5.0
# 1309009            1.0           1.0  Budweiser       5.0
# 1309011            1.5           1.5  Budweiser       5.0

# %%
second = cleandata[(cleandata.beer_name == beer2) & (cleandata.review_overall == overall2)]
second.head()
# Out:
#         review_overall  review_aroma  review_appearance review_profilename  \
# 669204             5.0           4.0                4.5            rtepiak
# 679191             5.0           4.0                5.0            Casconi
# 682190             5.0           4.5                5.0          Stephen63
# 683407             5.0           5.0                4.5        surfmeister
# 691224             5.0           4.5                5.0           brentk56
#
#         review_palate  review_taste                      beer_name  beer_abv
# 669204            5.0           4.0  Weihenstephaner Hefeweissbier       5.4
# 679191            4.5           5.0  Weihenstephaner Hefeweissbier       5.4
# 682190            5.0           5.0  Weihenstephaner Hefeweissbier       5.4
# 683407            4.5           5.0  Weihenstephaner Hefeweissbier       5.4
# 691224            5.0           5.0  Weihenstephaner Hefeweissbier       5.4

# %%
third = cleandata[(cleandata.beer_name == beer3) & (cleandata.review_overall == overall3)]
third.head()
# Out:
#         review_overall  review_aroma  review_appearance review_profilename  \
# 342467             3.0           3.0                4.0         jwinship83
# 342506             3.0           3.5                4.0     JaredWolgemuth
# 342527             3.0           4.5                3.5           nkersten
# 342528             3.0           2.5                3.5      SolomonGrundy
# 342561             3.0           3.5                4.0       CourteManche
#
#         review_palate  review_taste               beer_name  beer_abv
# 342467            2.5           3.0  Trappistes Rochefort 6       7.5
# 342506            3.5           4.0  Trappistes Rochefort 6       7.5
# 342527            3.5           3.0  Trappistes Rochefort 6       7.5
# 342528            4.0           3.5  Trappistes Rochefort 6       7.5
# 342561            4.0           4.0  Trappistes Rochefort 6       7.5

# %%
firstdata = first.append(second)
final = firstdata.append(third)
final.head()
# Out:
#          review_overall  review_aroma  review_appearance review_profilename  \
# 1308962             1.0           1.5                2.0      DarkBeerRuler
# 1308971             1.0           2.0                3.5       beachbum1975
# 1308991             1.0           1.5                1.5      HomelessShoes
# 1309009             1.0           1.5                3.0            xduderx
# 1309011             1.0           1.5                1.5    GratefulBeerGuy
#
#          review_palate  review_taste  beer_name  beer_abv
# 1308962            2.0           1.0  Budweiser       5.0
# 1308971            1.5           2.0  Budweiser       5.0
# 1308991            1.5           1.0  Budweiser       5.0
# 1309009            1.0           1.0  Budweiser       5.0
# 1309011            1.5           1.5  Budweiser       5.0

# %%
reviewer = final.loc[:,"review_profilename"]

# %%
reviewer = reviewer.values.tolist()
reviewer
# Out:
# ['DarkBeerRuler',
#  'beachbum1975',
#  'HomelessShoes',
#  'xduderx',
#  'GratefulBeerGuy',
#  'Erdinger2003',
#  'UncleFlip',
#  'andythejerk',
#  'casualbeerman',
#  'woodytele',
#  'DERTY1',
#  'brewbasser',
#  'DadOfMax',
#  'farside411',
#  'wnhay',
#  'cro250klr',
#  'BarrelBrother',
#  'StuFox',
#  'wailingwench',
#  'mynie',
#  'northyorksammy',
#  'engagechad',
#  'blitheringidiot',
#  'ngandhi',
#  'cptnjck101',
#  'CreamAle128',
#  'jwilli7122',
#  'wolfy',
#  'TheDM',
#  'rickyleepotts',
#  'Stubbie1',
#  'AtrumAnimus',
#  'Mick',
#  'cokes',
#  'psugrad98',
#  'aracauna',
#  'sponberg',
#  'Brent',
#  'Rifugium',
#  'afksports',
#  'hophopandaway',
#  'StoneTSR',
#  'wmtxbb',
#  'Bricelyn',
#  'majesticsock',
#  'brewski09',
#  'vdread',
#  'DerBayer',
#  'beergod1',
#  'Threelittlefish',
#  'OtherShoe2',
#  'Patrick999',
#  'eulcedes',
#  'bill93063',
#  'yuenglings',
#  'Bagman007',
#  'cbarrett',
#  'srrn',
#  'BoSox5902',
#  'Witbierlover',
#  'Bierman9',
#  'bltzburgh',
#  'mccordbmw',
#  'avalon07',
#  'imaguitargod',
#  'Wickenstein',
#  'pirates',
#  'auxiliary',
#  'BoxingFanatic',
#  'HiMyNameIsDerek',
#  'garbercury',
#  'mon0x1d3',
#  'wcudwight',
#  'rvdoorn',
#  'Clockwork420',
#  'umustdrink',
#  'simmons',
#  'tozerm',
#  'TechMyst',
#  'jayhawk73',
#  'harrymel',
#  'rtepiak',
#  'Casconi',
#  'Stephen63',
#  'surfmeister',
#  'brentk56',
#  'BeerMan7777777',
#  'br3wmeister',
#  'Thomajt',
#  'k3n',
#  'Riccymon',
#  'Fahmie25',
#  'HeadFullaHops',
#  'gonzo46and2',
#  'rslomin',
#  'DarthFedor',
#  'yeastsipper',
#  'unclejimbay',
#  'schroederm',
#  'Esper',
#  'CoolJosh',
#  'erz316',
#  'brewintheLou',
#  'xenolithic',
#  'BeerBubby',
#  'rudylaw',
#  'Gyle41386',
#  'wcudwight',
#  'KevinCurtis',
#  'mduncan',
#  'bfields4',
#  'popery',
#  'yemenmocha',
#  'mattXdezzi',
#  'chriskozma',
#  'leetyankees',
#  'glid02',
#  'LennyV',
#  'JBogan',
#  'Spikester',
#  'DrewSnyc667',
#  'BigJim5021',
#  'magictrokini',
#  'corby112',
#  'treyrab',
#  'reezun',
#  'lynx1245',
#  'ThreeWiseMen',
#  'Clydesdale',
#  'funkyspunk87',
#  'TheGrunt',
#  'musicman575',
#  'joepais',
#  'stumac',
#  'Marcus6679',
#  'gyllstromk',
#  'Reino',
#  'brushtachio',
#  'changeup45',
#  'CAMRAhardliner',
#  'scootny',
#  'meatmallet',
#  'simplexiton',
#  'rye726',
#  'AKBelgianBeast',
#  'mgp80',
#  'gford217',
#  'cswhitehorse',
#  'UGADawgGuy',
#  'PerzentRizen',
#  'OWSLEY069',
#  'Biscuit033',
#  'morimech',
#  'elniko',
#  'MSchae1017',
#  'frampin',
#  'everetends',
#  'Lnedrive14',
#  'SaucyA',
#  'hefeweizbier',
#  'AlsationBiere',
#  'msgraves',
#  'fishtownhxc',
#  'PeprSprYoFace',
#  'Rainintheface',
#  'rudzud',
#  'thehenbarris',
#  'oline73',
#  'Kartoffeln',
#  'gigi112086',
#  'Strix',
#  'ryrust5301',
#  'ShrLSU',
#  'pwoods',
#  'JonathanL7890',
#  'Matthias726',
#  '0110x011',
#  'Natural510',
#  'saintwarrick',
#  'Greggy',
#  'AlsationBiere',
#  'AmishT',
#  'bayoubeerguy',
#  'daythree16',
#  'WaveRebel51',
#  'BamaBeerBuff',
#  'JoeyBeerBelly',
#  'Kegatron',
#  'marcpal',
#  'Lupe',
#  'dyan',
#  'rkinsella',
#  'brucer1',
#  'HopDerek',
#  'Avryle',
#  'cabsandking',
#  'bort11',
#  'ScottUCF84',
#  'PedanticBrewing',
#  'Lexluthor33',
#  'drumrboy22',
#  'pokesbeerdude',
#  'Mudpuppet',
#  'baos',
#  'hwwty4',
#  'CrellMoset',
#  'tai4ji2x',
#  'LetsGoQuakers',
#  'Rudgers73',
#  'Rijtjeshuis',
#  'pheggeseth',
#  'DirtyPenny',
#  'kkipple',
#  'bluemoonswoon',
#  'BeerTaster',
#  'wheelinshirt',
#  'czfreeman',
#  'n0315',
#  'ibeplato',
#  'cstadoln',
#  'LittleCreature',
#  'armock',
#  'dsa7783',
#  'BlackHaddock',
#  'BradLikesBrew',
#  'Cyberkedi',
#  'TheSarge',
#  'viperpiper522',
#  'brendan13',
#  'Deutschlandic',
#  'Risser09',
#  'mschiefelbein',
#  'JavelinPride',
#  'Grundle20',
#  'soupyman10',
#  'burnstar',
#  'TheodorHerzl',
#  'TheManiacalOne',
#  'chieftjc',
#  'ponymaster',
#  'KevPet84',
#  'HotterThanHell',
#  'Slatetank',
#  'seanyfo',
#  'pojo41',
#  'gpcollen1',
#  'whiplash3825',
#  'Cs1987',
#  'BeerGut4Life',
#  'illidurit',
#  'Nesued',
#  'mikebeane',
#  'sbe1',
#  'DoubleJ',
#  'modpod',
#  'rohrbachsfan',
#  'MrHungryMonkey',
#  'bunnyhustle',
#  'philberinghele',
#  'dcteas17',
#  'MarkSCCOT',
#  'RutgersBeerGuy',
#  'kellyst',
#  'BladeRunner',
#  'emerge077',
#  'yemenmocha',
#  'jeffjfindley',
#  'cpn920',
#  'Bitterbill',
#  'letsgopens',
#  'drunkenmonk',
#  'Sudsdog',
#  'coalcracker',
#  'gmfessen',
#  'samercado',
#  'GimpyCane',
#  'Weizenmensch',
#  'BassAssassin',
#  'kajerm',
#  'travelfrog',
#  'SMark',
#  'clemtig76',
#  'mjc410',
#  'jmalex',
#  'LvilleIPA',
#  'liquorbucket',
#  'guitarmage',
#  'Byeast',
#  'MrHolland',
#  'Optimat0r',
#  'jdoolin',
#  'WasTrinkenSie',
#  'mrasskicktastic',
#  'techdiver',
#  'jonnyoyeah',
#  'thefenst',
#  'lagomswedish',
#  'quafster',
#  'rkowalick',
#  'SudNut',
#  'lpayette',
#  'Erdinger2003',
#  'rarevos',
#  'objectivemonkey',
#  'schoolboy',
#  'thebob',
#  'jarsh',
#  'BretSikkink',
#  'TexIndy',
#  'Hibernator',
#  'BurnsTau',
#  'JerzDevl2000',
#  'Blakaeris',
#  'Budlum',
#  'DaPeculierDane',
#  'SethB2',
#  'rousee',
#  'SteveO1231',
#  'AltBock',
#  'Damian',
#  'taez555',
#  'clickpush',
#  'karst',
#  'Phatz',
#  'codsmith',
#  'trep',
#  'cjgator3',
#  'nlmartin',
#  'CNeilP09',
#  'phisig137',
#  'scoobybrew',
#  'jaluria',
#  'goochpunch',
#  'Vinodiuz',
#  'DogFood11',
#  'kkipple',
#  'sammy44',
#  'Derek',
#  'Tupperwolf',
#  'pbr85',
#  'eb003',
#  'alexgash',
#  'kgotcher',
#  'nsmit17',
#  'chOAKbarrell',
#  'bennetj17',
#  'edchef1850',
#  'TheLongBeachBum',
#  'maddamish',
#  'yelterdow',
#  'Reaper16',
#  'kegerator',
#  'PatYoda',
#  'davidchollar',
#  'nortmand',
#  'DrJay',
#  'jpm30',
#  'goindownsouth',
#  'nickss',
#  'BeerBeing',
#  'Domingo',
#  'Vancer',
#  'wedge',
#  'tastybeer',
#  'ElGordo',
#  'kmpitz2',
#  'Dubblebock',
#  'Gritsak',
#  'thechaacster',
#  'RedBaron',
#  'tryemall',
#  'thesilverhand',
#  'GCBrewingCo',
#  'Naerhu',
#  'wnhay',
#  'cracgor',
#  'lacqueredmouse',
#  'goodbyeohio',
#  'MABZ',
#  'JeffTibbetts',
#  'kosmoraios',
#  'pixrob',
#  'mynie',
#  'malty',
#  'afatty',
#  'Luigi',
#  'stjarnflikka',
#  'wnhay',
#  'mobyfann',
#  'thefratguy',
#  'jvajda',
#  'Dmann',
#  'TikkiGodxxx',
#  'rdrummer',
#  'Buzzkill',
#  'usualpulp',
#  'finepaws',
#  'waughbrew',
#  'cokes',
#  'Gavage',
#  'Tballz420',
#  'cedricwarner',
#  '99bottles',
#  'kmcnair',
#  'Zorro',
#  'necoadam',
#  'rajendra82',
#  'TastyTaste',
#  'HardTarget',
#  'Winter',
#  'hulmanite',
#  'Ellbert',
#  'marburg',
#  'putnam',
#  'Zraly',
#  'au1sec',
#  'Boilermaker88',
#  'tavernjef',
#  'ZAP',
#  'dwarbi',
#  'kbub6f',
#  'daledeee',
#  'Morris729',
#  'pezoids',
#  'WMBierguy',
#  'AudioGilz',
#  'jackndan',
#  'MJR',
#  'aaronh',
#  'johnfurbock',
#  'mikes2923',
#  'StevieW',
#  'zerk',
#  'Kwak',
#  'Kwak',
#  'RBorsato',
#  'mzwolinski',
#  'AaronRed',
#  'marc77',
#  'rastaman',
#  'bk3nj',
#  'garymuchow',
#  'John',
#  'phillybeer7779',
#  'RashyGrillCook',
#  'budgood1',
#  'dragonWhale',
#  'garuda',
#  'smakawhat',
#  'Sharkophile',
#  'rtaps',
#  'Feareon',
#  'djbow',
#  'superspak',
#  'loobear',
#  'MattyG85',
#  'mostpoetsdo',
#  'CrystalPesci',
#  'SeaOfShells',
#  'BeerBodisafa',
#  'plfahey',
#  'godfathermg57',
#  'JohnnyS17',
#  'chiccabeer',
#  'Soneast',
#  'shanetemple',
#  'clarkm04',
#  'gskitt',
#  'desiderius',
#  'dbaker61',
#  'MrHurmateeowish',
#  'OnThenIn',
#  'dbossman',
#  'weizenbob',
#  'ffejherb',
#  'flipper2gv',
#  'MadCat',
#  'VirginiaSpirit',
#  'mjn5036',
#  'tbraun1',
#  'DeltaGolfSierra',
#  'Avagadro',
#  'guitarsnbeer',
#  'Taera',
#  'SacredBeverage',
#  'JohnnyChicago',
#  'MichialTanner1',
#  'Urbancaver',
#  'FosterJM',
#  'horshack7',
#  'depechemode1983',
#  'Stockfan42',
#  'ZenAgnostic',
#  'juhl31',
#  'GarrettM99',
#  'socon67',
#  'weisbierjeff',
#  'RyanWo',
#  'tobin',
#  'ms11781',
#  'madvermin',
#  'CuriousMonk',
#  'dasenebler',
#  'ticklechicken',
#  'dfclav',
#  'prdstmnky',
#  'dubinsky',
#  'Biggness',
#  'cudmud',
#  'cadizkyguy',
#  'DarthRadb',
#  'aasher',
#  'dansmcd',
#  'StormKing47',
#  'afksports',
#  'McCrae',
#  'gdrydenc',
#  'Clippers652',
#  'Mosley1212',
#  'DrVetur',
#  'basica',
#  'BEERMILER12',
#  'Prosper0',
#  'FanofHefe',
#  'JoEBoBpr',
#  'bigrzman',
#  'uustal',
#  'haazer',
#  'greenmonstah',
#  'josefnewsong',
#  'micmillon18',
#  'Bouleboubier',
#  'jesperm',
#  'PDX2LA',
#  'EwaldEichstaett',
#  'dutchlq7',
#  'DrDemento456',
#  'RickS95',
#  'djmichaelk',
#  'JohnnyP3',
#  'TheDinger',
#  'RossCain',
#  'keanex',
#  'RnRManifesto',
#  'ptykozoon',
#  'Vdubb86',
#  'yankiac',
#  'mbusster88',
#  'ElijahCSkuggs',
#  'milkbaby9',
#  'rand',
#  'Transatlantic',
#  'king75',
#  'hosehead83',
#  'elricorico',
#  'Arbitrator',
#  'zhanson88',
#  'Blanco',
#  'Dawkfan',
#  'billshmeinke',
#  'mwagner1018',
#  'Seanstoppable',
#  'TKEbeerman',
#  'GeoJ',
#  'cnally',
#  'nataku00',
#  'KAP1356',
#  'Whiteweasel',
#  'CalhounJohn',
#  'DNICE555',
#  'curly31989',
#  'Lukafer',
#  'Beejay',
#  'cvaypai',
#  'goblue3509',
#  'Huhzubendah',
#  'Fieldzy27',
#  'hayesez',
#  'chetti76',
#  'stimulus',
#  'chickencoop',
#  'DeliciousSeeker',
#  'RareMonkey',
#  'Augustiner719',
#  'NODAK',
#  'VTaler',
#  'bluesfan1181',
#  'JEdmund',
#  'DeutschesBier',
#  'leokbelo',
#  'beers2danno',
#  'Centennial',
#  'jampics2',
#  'mlazzaro',
#  'bagpiper2005',
#  'bsp77',
#  'pmccallum86',
#  'Luk13',
#  'rowey77',
#  'aquaphiliac',
#  'briggssteel',
#  'yeahnatenelson',
#  'Shuffledaddy',
#  'Mosstrooper',
#  'mithrascruor',
#  'AleWatcher',
#  'ElDavicho',
#  'Erish',
#  'BeerSingh',
#  'Krevee',
#  'Stunner97',
#  'Chico1985',
#  'Elimination',
#  'blausebas',
#  'gkunkle',
#  'claminat420',
#  'olympuszymurgus',
#  'beertunes',
#  'punkrkr27',
#  'BeerNemesis',
#  'BobZ',
#  'boss302',
#  'WhiteOak',
#  'wahhmaster',
#  'oteyj',
#  'Thur123',
#  'chriskc',
#  'eat',
#  'Superdaunte',
#  'Evocatus',
#  'yourefragile',
#  'kpoole25',
#  'bump8628',
#  'UCLABrewN84',
#  'keithmurray',
#  'MbpBugeye',
#  'epicness',
#  'ocmpoma',
#  'FreshHawk',
#  'scottyshades',
#  'TheSicilian33',
#  'Gosox8787',
#  'NatetheGreat',
#  'tippebrewcrew2',
#  'NYCWheatFanSC',
#  'pdoran10',
#  'Sunnanek',
#  'Minotaur',
#  'jlindros',
#  'WeezyBoPeep',
#  'KingEdward',
#  'acelin',
#  'Stavage',
#  'zacarias',
#  'marketesq',
#  'digitalketchup',
#  'ehammond1',
#  'harrymattcody',
#  'Thesis',
#  'Welsman',
#  'JohnnyBarman',
#  'chetripley',
#  'billab914',
#  'jizdepski',
#  'drabmuh',
#  'trbergman',
#  'EStreet20',
#  'SpeedwayJim',
#  'RuudJH',
#  'cptierney',
#  'kkipple',
#  'AmberMan22',
#  'Brenden',
#  'cbutova',
#  'Arnulf',
#  'kylegillick',
#  'CarlP2',
#  'dyan',
#  'BarleyAndApple',
#  'SIRIUS2',
#  'nickd717',
#  'sweemzander',
#  'jera1350',
#  'farrago',
#  'PerroGrande',
#  'generallee',
#  'r0nyn',
#  'augustgarage',
#  'seanthornton152',
#  'RyWill',
#  'woosterbill',
#  'kels',
#  'Stinkypuss',
#  'fropones',
#  'illinijer',
#  'MunchkinDrinker',
#  'benteach',
#  'patmcd',
#  'salisbury',
#  'crossovert',
#  'magine',
#  'spartikvs',
#  'GatorBeerNerd',
#  'batty',
#  'SirDrinxAlot',
#  'azorie',
#  'onix1agr',
#  'digitalhifi',
#  'adamette',
#  'mjnich',
#  'rpkelly',
#  'jcpaulun',
#  'jsh420',
#  'pradipta',
#  'barleywinefiend',
#  'funkengruven',
#  'steanu',
#  'PsychoJedi',
#  'MyGoodness',
#  'civilizedpsycho',
#  'drinkininthewood',
#  'malcontent',
#  'MeisterBurger',
#  'EatsTacos',
#  'drtth',
#  'junjun',
#  'seand',
#  'colts9016',
#  'MusicmanSD',
#  'stbfan',
#  'originalsin',
#  'callmescraps',
#  'natasharai',
#  'ocelot2500',
#  'OzarkElmo',
#  'cbarrett4',
#  'ejr1953',
#  'jeffthecheff',
#  'bwd110',
#  'cavedave',
#  'UA8',
#  'jakeblues',
#  'ritzkiss',
#  'webmanspidey',
#  'Thorpe429',
#  'ender10',
#  'Buschyfor3',
#  'hardy008',
#  'Liverpool08',
#  'Gambrinus1184',
#  'jjayjaye',
#  'carp420',
#  'Infamous7100',
#  'goblet',
#  'sevopie',
#  'PirateUlf73',
#  'hollis092',
#  'maddmatt48',
#  'NCBeernut',
#  'jjanega08',
#  'abfraser',
#  'gameface23',
#  'Brad007',
#  'CJthirty7',
#  'pmcadamis',
#  'imagineiii',
#  'ThirdLap',
#  'Shadman',
#  'lynchmob9',
#  'DrewOSU',
#  'JonMich13',
#  'Voonder',
#  'peterg321',
#  'paperbackfoster',
#  'aeolianshredhead',
#  'coopbrewer',
#  'jwinship83',
#  'JaredWolgemuth',
#  'nkersten',
#  'SolomonGrundy',
#  'CourteManche',
#  'babaracas',
#  'ne0m00re',
#  'MbpBugeye',
#  'hungerfordj',
#  'dancinwillie',
#  'Jeffo',
#  'Arbitrator',
#  'nlmartin',
#  'champ103',
#  'bluemoonswoon',
#  'JeffV',
#  'BMoney575',
#  'dsa7783',
#  'Marcus6679',
#  'pavandal',
#  'Damian',
#  'theopholis',
#  'khiasmus',
#  'RedHaze',
#  'kajerm',
#  'lagomswedish',
#  'IronDjinn',
#  'TheEclecticGent',
#  'seanyfo',
#  'Naerhu',
#  'drewbage',
#  'clvand0',
#  'pitasoup',
#  'smakawhat',
#  'alexhahn82']

# %%
finalresut = pd.DataFrame()
for allthename in reviewer:
    beername = allthename
    thefinalname = cleandata[(cleandata.review_profilename == beername) & (cleandata.review_overall == 5) 
                             & (cleandata.review_aroma == 5) & (cleandata.review_appearance == 5) 
                             & (cleandata.review_taste == 5)]
    #print(thefinalname)
    finalresut = finalresut.append(thefinalname)
finalresut.head()
# Out:
#         review_overall  review_aroma  review_appearance review_profilename  \
# 341063             5.0           5.0                5.0      DarkBeerRuler
# 157973             5.0           5.0                5.0       beachbum1975
# 415089             5.0           5.0                5.0       beachbum1975
# 84312              5.0           5.0                5.0       Erdinger2003
# 447988             5.0           5.0                5.0       Erdinger2003
#
#         review_palate  review_taste                               beer_name  \
# 341063            5.0           5.0                 Trappistes Rochefort 10
# 157973            4.5           5.0         Hoppe (Imperial Extra Pale Ale)
# 415089            4.5           5.0  Great Lakes Barrel-Aged Blackout Stout
# 84312             5.0           5.0           Sierra Nevada Celebration Ale
# 447988            5.0           5.0                          Raspberry Tart
#
#         beer_abv
# 341063      11.3
# 157973       8.0
# 415089       9.5
# 84312        6.8
# 447988       4.0

# %%
beernamefinal = finalresut.loc[:,"beer_name"]

# %%
beernamefinal = beernamefinal.values.tolist()
beernamefinal
# Out:
# ['Trappistes Rochefort 10',
#  'Hoppe (Imperial Extra Pale Ale)',
#  'Great Lakes Barrel-Aged Blackout Stout',
#  'Sierra Nevada Celebration Ale',
#  'Raspberry Tart',
#  'Oak Aged Dark Lord Imperial Stout',
#  'Yuengling Traditional Lager',
#  'Storm King Stout',
#  'Trappistes Rochefort 10',
#  'Harveys Christmas Ale',
#  'Masala Mama India Pale Ale',
#  'Shakespeare Oatmeal Stout',
#  'Shakespeare Oatmeal Stout',
#  'Gumballhead',
#  'Vanilla Bean Aged Dark Lord',
#  'Baller Stout',
#  'Dark Lord Imperial Stout',
#  'The Abyss',
#  'Ranger',
#  'Sneaky Pete Imperial IPA',
#  'La Folie',
#  'Shakespeare Oatmeal Stout',
#  'Bourbon County Brand Stout',
#  'Unibroue 10',
#  'Andechser Doppelbock Dunkel',
#  "Stoudt's Fat Dog (Imperial Oatmeal Stout)",
#  'Samuel Adams Double Bock (Imperial Series)',
#  'Double Simcoe IPA',
#  'Matilda',
#  'CoCoNut Porter',
#  'Ommegang (Abbey Ale)',
#  'Old Stock Ale',
#  'St. Sebastiaan Dark',
#  'Belle Vue Framboise',
#  'Avec Les Bons Voeux',
#  "McEwan's India Pale Ale",
#  "Samuel Smith's Oatmeal Stout",
#  'Hennepin (Farmhouse Saison)',
#  'Arrogant Bastard Ale',
#  'Cappa Cappa Crusher',
#  'Ayinger Celebrator Doppelbock',
#  'Old Salty Barleywine 2000',
#  'Abbaye Des Rocs [Brasserie Des Rocs Brune]',
#  "Samuel Smith's, The Famous Taddy Porter",
#  'Bourbon County Brand Stout',
#  'Stone Brew',
#  "Bell's Expedition Stout",
#  'De Ranke XX Bitter',
#  'Alexander Rodenbach',
#  'Andechser Doppelbock Dunkel',
#  'Dragonslayer',
#  'American Pale Ale',
#  'Sierra Nevada Stout',
#  'Bourbon Barrel Stout',
#  'Scotch Ale',
#  'Oat Malt Stout',
#  'Mocha Porter',
#  'Smooth Oatmeal Stout',
#  'Smooth India Pale Ale',
#  'Oktoberfest',
#  'Wee Heavy',
#  'Ayinger Celebrator Doppelbock',
#  'Edelweiss Dunkel Weissbier',
#  'Tucher Kristall Weizen',
#  'Old Rasputin Russian Imperial Stout',
#  'Anchor Liberty Ale',
#  'Anchor Porter',
#  "Young's Oatmeal Stout",
#  'Live Oak HefeWeizen',
#  'Spanish Peaks White Ale',
#  'Knuckle Sandwich',
#  'Jaipur IPA',
#  'Moose Drool Brown Ale',
#  'Red Chair NWPA',
#  'Three Philosophers Belgian Style Blend (Quadrupel)',
#  'Sierra Nevada Celebration Ale',
#  'Andechser Doppelbock Dunkel',
#  'Schneider-Brooklyner Hopfen-Weisse',
#  'Schneider Aventinus',
#  'Foret',
#  '90 Minute IPA',
#  'D.O.R.I.S. The Destroyer Double Imperial Stout',
#  'Great Lakes Blackout Stout',
#  'Hell',
#  'LongShot Old Ale',
#  'Guinness Draught',
#  'Trappist Westvleteren 12',
#  'Pisgah Valdez',
#  'Drie Fonteinen Oude Geuze 1998 (50th Anniversary)',
#  'Drie Fonteinen Millennium Gueuze',
#  "Armand'4 Oude Geuze Lente (Spring)",
#  'Drie Fonteinen Hommage',
#  'Kaggen! Stormaktsporter',
#  'Stormaktsporter',
#  'Black Damnation V - Double Black',
#  'Ziel & Zaligheid',
#  'Trappist Westvleteren 12',
#  'Guinness Draught',
#  'Our Special Ale 2003 (Anchor Christmas Ale)',
#  'Our Special Ale 1996 (Anchor Christmas Ale)',
#  'Alaskan Smoked Porter',
#  "Bell's Kalamazoo Stout",
#  '60 Minute IPA',
#  "Young's Double Chocolate Stout",
#  'Pliny The Elder',
#  'Trappist Westvleteren 8',
#  'Samuel Adams Boston Lager',
#  'Spaten Münchner Hell (Premium Lager)',
#  'Fred',
#  'Salvation',
#  'Allagash Tripel Ale',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'La Trappe Dubbel (Koningshoeven / Dominus)',
#  'Great Lakes Barrel-Aged Blackout Stout',
#  'Double Simcoe IPA',
#  'Weihenstephaner Hefeweissbier',
#  'Tripel Karmeliet',
#  'Three Philosophers Belgian Style Blend (Quadrupel)',
#  'Ayinger Celebrator Doppelbock',
#  'Palo Santo Marron',
#  'Old Rasputin Russian Imperial Stout',
#  'Sierra Nevada Kellerweis Hefeweizen',
#  'Sierra Nevada Pale Ale',
#  'Sierra Nevada Pale Ale',
#  'Sierra Nevada Torpedo Extra IPA',
#  'Sweetwater IPA',
#  'Raspberry Tart',
#  'Weihenstephaner Hefeweissbier',
#  "Bell's Hopslam Ale",
#  'Two Hearted Ale',
#  'Trappist Westvleteren 12',
#  'Trappist Westvleteren 8',
#  'Deviation - Bottleworks 9th Anniversary',
#  'Black Tuesday',
#  'Trappist Westvleteren 12',
#  'Chocolate Stout',
#  'Weihenstephaner Hefeweissbier',
#  'Ayinger Celebrator Doppelbock',
#  'Pliny The Elder',
#  'Darkness',
#  'Wooden Hell',
#  'Pliny The Elder',
#  'Portsmouth Kate The Great',
#  'Masala Mama India Pale Ale',
#  'Pisgah Valdez',
#  'Trappist Westvleteren 12',
#  'Pliny The Younger',
#  'Samuel Adams Boston Lager',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'Duvel',
#  'Ayinger Celebrator Doppelbock',
#  'Ayinger Bräu Weisse',
#  'Weihenstephaner Hefeweissbier',
#  'Oaked Arrogant Bastard Ale',
#  'Brooklyner-Schneider Hopfen-Weisse',
#  'Trappist Westvleteren 8',
#  'Stone IPA (India Pale Ale)',
#  'Two Hearted Ale',
#  'Mean Manalishi Double I.P.A.',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Yeti Imperial Stout',
#  'Hitachino Nest Espresso Stout',
#  'Drie Fonteinen Millennium Gueuze',
#  "Armand'4 Oude Geuze Lente (Spring)",
#  'Darkness',
#  'Lost & Found Abbey Ale',
#  "The Angel's Share - Brandy Barrel-Aged",
#  'Stone Ruination IPA',
#  'Stone Imperial Russian Stout',
#  "Bell's Hopslam Ale",
#  "Bell's Expedition Stout",
#  'Kaggen! Stormaktsporter',
#  'Pannepot',
#  'Ølfabrikken Porter',
#  'World Wide Stout',
#  'Old Rasputin Russian Imperial Stout',
#  'Gouden Carolus Classic',
#  'Storm King Stout',
#  'M Belgian-Style Barleywine',
#  'Bourbon County Brand Stout',
#  'Pliny The Elder',
#  'AleSmith Old Numbskull',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'Andechser Doppelbock Dunkel',
#  'Portsmouth Pils Von Faust',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Maharaja',
#  'Dark Horse One Oatmeal Stout Ale',
#  'Dirty Old Man Imperial Rye Porter',
#  'Old Stock Ale',
#  'Our Special Ale 2003 (Anchor Christmas Ale)',
#  'St. Bernardus Abt 12',
#  'Founders Breakfast Stout',
#  'Hop Rod Rye',
#  'Oak Aged Yeti Imperial Stout',
#  'Weihenstephaner Hefeweissbier',
#  'Stone Imperial Russian Stout',
#  'J.W. Lees Vintage Harvest Ale',
#  'Rodenbach Grand Cru',
#  'Old Rasputin Russian Imperial Stout',
#  'Trappist Westvleteren 8',
#  'Cantillon Lou Pepe - Gueuze',
#  'Cantillon Saint Lamvinus',
#  'Drie Fonteinen Oude Kriek',
#  'Girardin Gueuze 1882 (Black Label)',
#  'Black Damnation V - Double Black',
#  'Pliny The Elder',
#  'Weihenstephaner Hefeweissbier',
#  'Guinness Foreign Extra Stout',
#  'AleSmith Speedway Stout - Barrel Aged',
#  'Royal Oil',
#  'Cable Car',
#  'Isabelle Proximus',
#  'Kuhnhenn Nine Braggot',
#  'J.W. Lees Vintage Harvest Ale',
#  'Bourbon Barrel Aged Imperial Stout',
#  'Da Yoopers',
#  'Dark Lord Imperial Stout',
#  'Portsmouth Kate The Great',
#  "Thomas Hardy's Ale (1968-1999)",
#  'Weihenstephaner Hefeweissbier',
#  'Schneider Aventinus',
#  'Pliny The Younger',
#  'Cuvee Delphine',
#  'Two Hearted Ale',
#  'Weihenstephaner Hefeweissbier',
#  'Exponential Hoppiness',
#  'Isabelle Proximus',
#  "The Angel's Share - Bourbon Barrel-Aged",
#  'Stone Ruination IPA Double Dry Hopped',
#  'Trappist Westvleteren 12',
#  'Kiwi Rising',
#  'Lost Sailor IPA Aged In Cab Barrels',
#  'Double Jack',
#  'Sculpin India Pale Ale',
#  "Fisherman's Imperial Pumpkin Stout",
#  'Fantôme Saison',
#  'Weihenstephaner Hefeweissbier',
#  "Hunahpu's Imperial Stout - Whiskey Barrel Aged",
#  'AleSmith Speedway Stout',
#  'Smuttynose IPA "Finest Kind"',
#  'Sculpin India Pale Ale',
#  'Furious',
#  'Furious',
#  'Vanilla Bean Aged Dark Lord',
#  'Live Oak HefeWeizen',
#  'Firestone 12 - Anniversary Ale',
#  'Firestone 11 - Anniversary Ale',
#  "The Angel's Share - Bourbon Barrel-Aged",
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'Anchor Liberty Ale',
#  'The Abyss',
#  'Saison Dupont',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'Ayinger Celebrator Doppelbock',
#  'Tröegs Nugget Nectar',
#  'Founders Breakfast Stout',
#  'Double Simcoe IPA',
#  'Shakespeare Oatmeal Stout',
#  'Chocolate Indulgence Stout',
#  'Bender',
#  'Drie Fonteinen Oude Geuze',
#  'Pliny The Younger',
#  'Portsmouth Kate The Great',
#  'Old Rasputin Russian Imperial Stout',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'The Abyss',
#  'Piraat Ale',
#  "Raison D'etre",
#  'Mackeson Triple XXX Stout',
#  'Two Hearted Ale',
#  'Trappistes Rochefort 8',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'Pumking',
#  'Hoegaarden Original White Ale',
#  'Blanche De Chambly',
#  'Tröegs Nugget Nectar',
#  'Ayinger Bräu Weisse',
#  'Bodacious Black & Tan',
#  'Sweetwater IPA',
#  "Twain's XL Double IPA",
#  'Péché Mortel (Imperial Stout Au Cafe)',
#  'Rogue Black Brutal',
#  'Shakespeare Oatmeal Stout',
#  'Pisgah Valdez',
#  "Serpent's Stout",
#  'Terminator Stout',
#  'Black Hole (White Wine Edition)',
#  'Black Hole',
#  'Fra Til (From To)',
#  'Ølfabrikken Porter',
#  'Heavy Seas - Siren Noire Imperial Chocolate Stout',
#  "Odin's Tipple",
#  'Jemmy American Stout',
#  "Young's Double Chocolate Stout",
#  'Weihenstephaner Hefeweissbier Dunkel',
#  'Weihenstephaner Hefeweissbier',
#  'Tripel Karmeliet',
#  "Bell's Hopslam Ale",
#  'Augustiner Bräu Edelstoff',
#  '90 Minute IPA',
#  'Tröegs Nugget Nectar',
#  'Weihenstephaner Hefeweissbier',
#  'Sculpin India Pale Ale',
#  'Flower Power India Pale Ale',
#  'Brute',
#  'Cable Car',
#  'Live Oak HefeWeizen',
#  'Weihenstephaner Hefeweissbier',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Masala Mama India Pale Ale',
#  'Dreadnaught IPA',
#  'Aecht Schlenkerla Rauchbier Urbock',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'AleSmith Speedway Stout',
#  'AleSmith Speedway Stout',
#  'YuleSmith (Winter)',
#  'Baudelaire IO',
#  'The Abyss',
#  'Trappist Westvleteren 12',
#  'Trappist Westvleteren 8',
#  'Trappistes Rochefort 10',
#  'Supplication',
#  'Péché Mortel (Imperial Stout Au Cafe)',
#  'Great Lakes Edmund Fitzgerald Porter',
#  'Chocolate Stout',
#  "Bell's Expedition Stout",
#  'Maillot Jaune',
#  'Schneider Weisse Original',
#  'Samuel Adams Boston Lager',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'Duvel',
#  'Ayinger Celebrator Doppelbock',
#  'Ayinger Bräu Weisse',
#  'Trappistes Rochefort 10',
#  'Maharaja',
#  'Ayinger Celebrator Doppelbock',
#  'Terminal Gravity IPA',
#  'Kuhnhenn Raspberry Eisbock',
#  'Brasserie Des Rocs Triple Impériale',
#  'DeuS (Brut Des Flandres)',
#  'New Holland Night Tripper',
#  '3 Monts',
#  'SkullSplitter',
#  'Prima Pils',
#  'Cantillon Saint Lamvinus',
#  'Weihenstephaner Hefeweissbier',
#  'Weihenstephaner Hefeweissbier',
#  'Anchor Porter',
#  'Ayinger Celebrator Doppelbock',
#  'Hofbräu Munich Weizen',
#  'Matilda',
#  'Weihenstephaner Hefeweissbier',
#  'Brasserie Des Rocs Triple Impériale',
#  'Ayinger Celebrator Doppelbock',
#  'Sierra Nevada Celebration Ale',
#  'Raspberry Tart',
#  'Darkness',
#  'Weihenstephaner Hefeweissbier',
#  'Unplugged Imperial Weizen',
#  'Victory At Sea Coffee Vanilla Imperial Porter',
#  'Maharaja',
#  'Weihenstephaner Hefeweissbier',
#  'Tripel Karmeliet',
#  'Cable Car',
#  'Franziskaner Hefe-Weisse',
#  'Smoke Jumper Smoked Imperial Porter',
#  'Bourbon County Brand Stout',
#  'Trappist Westvleteren 12',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Morimoto Imperial Pilsner',
#  'Shakespeare Oatmeal Stout',
#  "Samuel Smith's Imperial Stout",
#  'Stone Imperial Russian Stout',
#  'The Abyss',
#  'Trappistes Rochefort 10',
#  'Raspberry Tart',
#  'Unplugged Imperial Weizen',
#  'Red Brick Double IPA',
#  'Oak Aged Dark Lord Imperial Stout',
#  'Vanilla Bean Aged Dark Lord',
#  'Sierra Nevada Bigfoot Barleywine Style Ale',
#  'Double Bastard Ale',
#  'Storm King Stout',
#  'Founders Breakfast Stout',
#  'Samichlaus Bier',
#  'Oak Aged Dark Lord Imperial Stout',
#  'Dreadnaught IPA',
#  'Dark Lord Imperial Stout',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Oak Aged Dark Lord Imperial Stout',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Hop Rod Rye',
#  'Péché Mortel (Imperial Stout Au Cafe)',
#  'Ommegang (Abbey Ale)',
#  'Stone 10th Anniversary IPA',
#  'Stone Imperial Russian Stout',
#  "Bell's Hopslam Ale",
#  'J.W. Lees Vintage Harvest Ale',
#  'Big Eddy Russian Imperial Stout',
#  'Dark Lord Imperial Stout',
#  'Shakespeare Oatmeal Stout',
#  'Schneider Aventinus',
#  'India Pale Ale',
#  'Brooklyn Black Chocolate Stout',
#  'Orval Trappist Ale',
#  'Hitachino Nest Weizen',
#  'Chocolate Stout',
#  'Fantôme Saison',
#  'Witte Trappist',
#  'Frambozenbier',
#  'Wittekerke Rosé',
#  'Redbach',
#  'Straffe Hendrik Blonde',
#  'Stiegl Goldbräu',
#  'St. Bernardus Abt 12',
#  'Green Flash West Coast I.P.A.',
#  'Orval Trappist Ale',
#  'Firestone 10 - Anniversary Ale',
#  'Unfiltered Double Barrel Ale',
#  'Stone Imperial Russian Stout',
#  'Pliny The Elder',
#  'Old Rasputin Russian Imperial Stout',
#  'Masala Mama India Pale Ale',
#  "Bell's Expedition Stout",
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Stone Imperial Russian Stout',
#  "Thomas Hardy's Ale (1968-1999)",
#  'Sierra Nevada Pale Ale',
#  "Samuel Smith's Nut Brown Ale",
#  'Lindemans Framboise',
#  'Ayinger Celebrator Doppelbock',
#  'Ayinger Bräu Weisse',
#  'Anchor Steam Beer',
#  'Abbaye Des Rocs Grand Cru Belgian Special Brown',
#  'Cantillon Gueuze 100% Lambic',
#  'Pliny The Younger',
#  'Courage Russian Imperial Stout',
#  "Thomas Hardy's Ale (1968-1999)",
#  'Trappist Westvleteren 12',
#  'Trappist Westvleteren 8',
#  'Reality Czeck',
#  'Trappistes Rochefort 10',
#  'Dreadnaught IPA',
#  'Aecht Schlenkerla Rauchbier Urbock',
#  'Peeper Ale',
#  'Tröegs Nugget Nectar',
#  'Weihenstephaner Hefeweissbier',
#  'Tripel Karmeliet',
#  'Saison Dupont',
#  'Sierra Nevada Bigfoot Barleywine Style Ale',
#  "Pete's Brown (Tribute Ale)",
#  'Chimay Grande Réserve (Blue)',
#  'Abbaye Des Rocs Grand Cru Belgian Special Brown',
#  'Hazelnut Brown Nectar',
#  "Samuel Smith's Imperial Stout",
#  'Weihenstephaner Hefeweissbier',
#  'Ommegang (Abbey Ale)',
#  'Schneider Aventinus',
#  'Smuttynose Big A IPA (Big Beer Series)',
#  'Alpha King Pale Ale',
#  'Fantôme Black Ghost',
#  'Trappist Westvleteren 8',
#  'HopDevil Ale',
#  'Whirlwind Witbier',
#  'Moonglow Weizenbock',
#  'Storm King Stout',
#  'Prima Pils',
#  'St. Victorious',
#  'Old Horizontal',
#  'Founders Breakfast Stout',
#  'Founders Black Rye',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Sierra Nevada Bigfoot Barleywine Style Ale',
#  'Bam Bière',
#  'Weihenstephaner Hefeweissbier',
#  'Stone Imperial Russian Stout',
#  'Westmalle Trappist Dubbel',
#  'Fred',
#  'Brooklyn Black Chocolate Stout',
#  'J.W. Lees Vintage Harvest Ale',
#  'Andechser Doppelbock Dunkel',
#  'Hofbräu Weiße',
#  'Weihenstephaner Original',
#  'Weihenstephaner Hefeweissbier',
#  'Storm King Stout',
#  'Andechser Doppelbock Dunkel',
#  'Dark Lord Imperial Stout',
#  'Trappist Westvleteren 8',
#  "Drake's Barrel Aged Barley Wine",
#  "Stoudt's Fat Dog (Imperial Oatmeal Stout)",
#  'Hennepin (Farmhouse Saison)',
#  'Dragonslayer',
#  'YuleSmith (Summer)',
#  'Trappist Westvleteren 12',
#  'Trappist Westvleteren 8',
#  'Hercules Double IPA',
#  'Darken Boar Wheat Special',
#  'Hitachino Nest Amber Ale',
#  'Dead Guy Ale',
#  'Stone Imperial Russian Stout',
#  'Sapporo Edelpils',
#  'Pliny The Younger',
#  'Mackeson Triple XXX Stout',
#  'Édition 2005',
#  'Charlie (JLS Release #22)',
#  'Weihenstephaner Hefeweissbier',
#  'Allagash Tripel Ale',
#  'St-Ambroise Stout Impériale Russe',
#  'Bourbon County Brand Stout',
#  'George! Bourbonfadlagret',
#  'St. Bernardus Pater 6',
#  'Trappistes Rochefort 10',
#  'Orval Trappist Ale',
#  'Trappist Westvleteren 12',
#  'St. Bernardus Abt 12',
#  'Weihenstephaner Hefeweissbier',
#  'Stone Imperial Russian Stout',
#  'J.W. Lees Vintage Harvest Ale',
#  'Masala Mama India Pale Ale',
#  'Shakespeare Oatmeal Stout',
#  'Shakespeare Oatmeal Stout',
#  'Gumballhead',
#  'Vanilla Bean Aged Dark Lord',
#  'Baller Stout',
#  'Dark Lord Imperial Stout',
#  'The Abyss',
#  'Plank Bavarian Heller Weizenbock',
#  'Burton Baton',
#  'Sierra Nevada Celebration Ale',
#  'Sierra Nevada Celebration Ale',
#  'Cantillon Rosé De Gambrinus',
#  "Mephistopheles' Stout",
#  'Weihenstephaner Hefeweissbier',
#  'Stone Sublimely Self-Righteous Ale',
#  'Stone Sublimely Self-Righteous Ale',
#  'Double Bastard Ale',
#  'Stone Old Guardian Barley Wine Style Ale 2008',
#  'Ayinger Celebrator Doppelbock',
#  'Old Rasputin Russian Imperial Stout',
#  'Black Butte XX',
#  'Weihenstephaner Hefeweissbier',
#  'McAuslan Vintage Ale (2001)',
#  'Maudite',
#  'De Ranke XX Bitter',
#  'St. Bernardus Abt 12',
#  'Abbaye Des Rocs [Brasserie Des Rocs Brune]',
#  "Samuel Smith's, The Famous Taddy Porter",
#  'Bourbon County Brand Stout',
#  'Stone Brew',
#  "Bell's Expedition Stout",
#  'De Ranke XX Bitter',
#  'The Abyss',
#  'Cantillon Kriek 100% Lambic',
#  'Oaked Arrogant Bastard Ale',
#  'Pliny The Elder',
#  'Dreadnaught IPA',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'La Terrible',
#  "Samuel Smith's Oatmeal Stout",
#  'Samichlaus Bier',
#  'Ayinger Celebrator Doppelbock',
#  'Trappist Westvleteren 8',
#  'Thomas Hooker Liberator Doppelbock',
#  'Ommegang (Abbey Ale)',
#  'Sierra Nevada Celebration Ale',
#  'Stone Ruination IPA',
#  'Masala Mama India Pale Ale',
#  'Abbaye Des Rocs Grand Cru Belgian Special Brown',
#  'Raspberry Tart',
#  "Santa's Private Reserve Ale",
#  'Weihenstephaner Korbinian',
#  'Weihenstephaner Hefeweissbier',
#  "Bell's Best Brown",
#  "Fuller's Vintage Ale",
#  'Dreadnaught IPA',
#  'Dark Lord Imperial Stout',
#  'Trappist Westvleteren 12',
#  'St. Bernardus Abt 12',
#  'Trappistes Rochefort 10',
#  'Wisconsin Belgian Red',
#  'Stone Imperial Russian Stout',
#  'Weihenstephaner Hefeweissbier',
#  'Bourbon County Brand Stout',
#  'La Folie',
#  'Cantillon Rosé De Gambrinus',
#  'DeuS (Brut Des Flandres)',
#  'Lindemans Gueuze Cuvée René',
#  'Rodenbach Classic (Red)',
#  'Alexander Rodenbach',
#  'Rodenbach Grand Cru',
#  'Mönchshof Schwarzbier',
#  'Trappist Westvleteren 8',
#  'Original Flag Porter',
#  'Zinnebir',
#  'Twelve Days',
#  'Samichlaus Bier',
#  'Southampton Cuvee Des Fleurs',
#  'Birra Del Vecchio Calabrese',
#  'Chimay Grande Réserve (Blue)',
#  'Chimay Tripel (White)',
#  'Chimay Première (Red)',
#  'Péché Mortel (Imperial Stout Au Cafe)',
#  'Samuel Adams Triple Bock',
#  'Hitachino Nest White Ale',
#  'Hitachino Nest Weizen',
#  'Baladin Nora',
#  'Uerige Sticke',
#  'Cantillon Lou Pepe - Framboise',
#  'Dead Guy Ale',
#  "Mahr's Hell",
#  'Hansje Drinker',
#  "Gale's Christmas Ale",
#  'Drie Fonteinen Kriek',
#  'DeuS (Brut Des Flandres)',
#  'Rothaus Eis Zäpfle',
#  'Tannenzäpfle',
#  'Reinaert Flemish Wild Ale',
#  'Hennepin (Farmhouse Saison)',
#  'Lindemans Gueuze Cuvée René',
#  'De Ranke XX Bitter',
#  'Sapporo Original Draft Beer',
#  'Westmalle Trappist Tripel',
#  'Wolnzacher Oktoberfest-Bier',
#  'Rodenbach Classic (Red)',
#  'Rodenbach Grand Cru',
#  'Oude Gueuze',
#  'Old Speckled Hen',
#  "Thomas Hardy's Ale (1968-1999)",
#  'Trappist Westvleteren 12',
#  'Trappist Westvleteren 8',
#  'St. Bernardus Abt 12',
#  'St. Bernardus Prior 8',
#  'Grottenbier',
#  'St. Bernardus Tripel',
#  'Panil Barriquée  (Italy Version)',
#  'St. Bernardus Abt 12',
#  'Alaskan Smoked Porter',
#  'Frank Double IPA',
#  'Double Bastard Ale',
#  "Bell's Expedition Stout",
#  'St. Bernardus Tripel',
#  'Ramstein Winter Wheat',
#  'Samuel Adams Imperial Stout',
#  'Euphoric',
#  'Oak Aged Twisted Reality',
#  'Raspberry Tart',
#  'Weihenstephaner Korbinian',
#  'Stone Old Guardian Barley Wine Style Ale 2001',
#  "Bell's Hopslam Ale",
#  "Bell's Expedition Stout",
#  'Westmalle Trappist Tripel',
#  'J.W. Lees Vintage Harvest Ale',
#  'Devil Over A Barrel - Bourbon Barrel-Aged Coffee Imperial Oatmeal Porter',
#  'Old Horizontal',
#  'Edmund Fitzgerald Imperial Stout (Bourbon Barrel Aged)',
#  'Storm King Stout',
#  'Live Oak HefeWeizen',
#  'St. Bernardus Abt 12',
#  'Blanche De Chambly',
#  'La Fin Du Monde',
#  'Maudite',
#  'Hennepin (Farmhouse Saison)',
#  'Stone Imperial Russian Stout',
#  'Duvel',
#  'Delirium Tremens',
#  'Live Oak HefeWeizen',
#  'Paulaner Hefe-Weissbier Naturtrüb',
#  'Storm King Stout',
#  "Samuel Smith's Winter Welcome Ale",
#  'Maredsous 8 - Dubbel',
#  'Rodenbach Grand Cru',
#  'Gumballhead',
#  'Alpha Klaus Christmas (Xmas) Porter',
#  'Storm King Stout',
#  'Weihenstephaner Hefeweissbier Dunkel',
#  'Sinebrychoff Porter',
#  'Samuel Adams Boston Ale (Stock Ale)',
#  'Weihenstephaner Hefeweissbier',
#  'Two Hearted Ale',
#  "Bell's Kalamazoo Stout",
#  'Saison Dupont',
#  'Fantôme Saison',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  'Stone IPA (India Pale Ale)',
#  'Stone Imperial Russian Stout',
#  'Two Hearted Ale',
#  'Storm King Stout',
#  'Alpha Klaus Christmas (Xmas) Porter',
#  'Maudite',
#  'Weihenstephaner Hefeweissbier',
#  'Franziskaner Hefe-Weisse',
#  'James Squire Amber Ale',
#  'Paulaner Hefe-Weissbier Naturtrüb',
#  'Blanche De Brooklyn',
#  'Brooklyner Weisse',
#  'Brooklyn Brown Ale',
#  'Dixie Blackened Voodoo Lager',
#  'Maudite',
#  'Weihenstephaner Hefeweissbier',
#  'Franziskaner Hefe-Weisse',
#  'James Squire Amber Ale',
#  'Paulaner Hefe-Weissbier Naturtrüb',
#  'Blanche De Brooklyn',
#  'Brooklyner Weisse',
#  'Brooklyn Brown Ale',
#  'Dixie Blackened Voodoo Lager',
#  'Sierra Nevada Celebration Ale',
#  'Sierra Nevada Pale Ale',
#  'Ramstein Oktoberfest',
#  'Chimay Première (Red)',
#  'Oscars Stout',
#  'Tröegs Hopback Amber Ale',
#  'Great Lakes Dortmunder Gold',
#  'Schlafly Coffee Stout',
#  'Hapkin',
#  "Ellie's Brown Ale",
#  'India Pale Ale (IPA)',
#  'Weihenstephaner Hefeweissbier',
#  'Highland Oatmeal Porter',
#  'Rock Creek Black Raven Porter',
#  'Andelot Cuvee Diabolique',
#  'Lindemans Framboise',
#  'I.P.A.',
#  'Duck-Rabbit Brown Ale',
#  'American Brown Ale',
#  'Duvel',
#  'Saison Dupont',
#  'Dominion Summer Wheat 2003',
#  'New River Pale Ale',
#  'New River Pale Ale',
#  'Ayinger Celebrator Doppelbock',
#  'Winter Ale Special Edition 2004-05',
#  'St. Nikolaus Bock Bier',
#  'Snake River Zonker Stout',
#  'Witkap Pater Singel / Stimulo',
#  'Robust Porter',
#  "Fuller's Special Edition ESB",
#  "Fuller's London Pride",
#  'Burton Baton',
#  'Clipper City Gold Ale',
#  'Heavy Seas - Winter Storm ("Category 5" Ale)',
#  'Allagash White',
#  'St. Feuillien Brune',
#  'Blue Ridge Subliminator Dopplebock',
#  "Ruedrich's Red Seal Ale",
#  "Zebulon's Peated Porter",
#  'Herold Bohemian Black Lager',
#  "Young's Double Chocolate Stout",
#  'Cottonwood Endo India Pale Ale',
#  'Audacious Apricot Ale',
#  'Storm King Stout',
#  'Moose Juice Stout',
#  'AleSmith Speedway Stout',
#  'Dark Lord Imperial Stout',
#  'Hacker-Pschorr Dunkle Weisse',
#  'Mocha Porter',
#  'Theakston Old Peculier',
#  'St. Bernardus Tripel',
#  'Stone 5th Anniversary IPA',
#  'Traquair Jacobite',
#  'Chimay Première (Red)',
#  'Weihenstephaner Hefeweissbier',
#  'Spaten Optimator',
#  "Samuel Smith's Oatmeal Stout",
#  'Paulaner Hefe-Weissbier Naturtrüb',
#  'Pride Of Milford Special Ale',
#  'Northern Hemisphere Harvest Wet Hop Ale',
#  'Pale Ale',
#  'Chimay Grande Réserve (Blue)',
#  'Samuel Adams Scotch Ale',
#  'Mad Hopper Pale Ale',
#  'Don de Dieu',
#  'Eau Benite',
#  'Maudite',
#  'Zatte',
#  "Younger's Special Bitter",
#  'Shakespeare Oatmeal Stout',
#  'Mogul Madness (JLS Release #2)',
#  'Chocolate Stout',
#  'Empire Doppelbock',
#  'Weihenstephaner Hefeweissbier',
#  'Rare Vos (Amber Ale)',
#  'Hennepin (Farmhouse Saison)',
#  'Schneider Weisse Weizenhell (Hefeweizen)',
#  'Duvel',
#  'Dragonslayer',
#  'ImPaled Ale',
#  'Ayinger Celebrator Doppelbock',
#  'Smuttynose Shoals Pale Ale',
#  "Fuller's ESB",
#  'Bush Ambrée',
#  'Rohrbachs 10th Anniversary Ale',
#  'Flour City IPA',
#  'Scotch Ale',
#  "Ruedrich's Red Seal Ale",
#  'Dreadnaught IPA',
#  'Alpha King Pale Ale',
#  'Delirium Tremens',
#  'Zywiec Porter',
#  'Paulaner Hefe-Weissbier Naturtrüb',
#  'Brooklyn Black Chocolate Stout',
#  'HopDevil Ale',
#  'Storm King Stout',
#  'Old Horizontal',
#  'Sinebrychoff Porter',
#  'Wisconsin Belgian Red',
#  'Dead Guy Ale',
#  "Santa's Private Reserve Ale",
#  "Samuel Smith's Imperial Stout",
#  'Bourbon County Brand Stout',
#  "Bell's Expedition Stout",
#  'Ayinger Celebrator Doppelbock',
#  'Mackeson Triple XXX Stout',
#  'Old Rasputin Russian Imperial Stout',
#  'Weihenstephaner Hefeweissbier',
#  'Founders CBS Imperial Stout',
#  'Citra DIPA',
#  'The Abyss',
#  'Weihenstephaner Hefeweissbier',
#  'Dreadnaught IPA',
#  'Trappist Westvleteren 12',
#  'Brooklyn Local 1',
#  'Choklat',
#  'Weihenstephaner Korbinian',
#  "Ruedrich's Red Seal Ale",
#  'Ten FIDY',
#  'Tröegs Nugget Nectar',
#  'Weihenstephaner Vitus',
#  'Temptation',
#  'Duvel Tripel Hop',
#  'Stone IPA (India Pale Ale)',
#  'Two Hearted Ale',
#  'Founders CBS Imperial Stout',
#  'Founders Breakfast Stout',
#  'Founders SZRP Of Doom',
#  'Guava Grove Saison',
#  'Barrel Aged Yeti',
#  'Péché Mortel (Imperial Stout Au Cafe)',
#  'Samuel Adams Utopias',
#  'Vermonster',
#  'Trappistes Rochefort 10',
#  'Orval Trappist Ale',
#  'Weizen Bam',
#  "Mephistopheles' Stout",
#  'Drie Fonteinen Oude Geuze',
#  'Schneider Aventinus Weizen-Eisbock',
#  'Stone 07.07.07 Vertical Epic Ale',
#  'Stone IPA (India Pale Ale)',
#  'Kona Coffee Macadamia Coconut Porter',
#  'Smuttynose Wheat Wine (Big Beer Series)',
#  'Palo Santo Marron',
#  'Old Rasputin Russian Imperial Stout',
#  'Old Stock Ale',
#  'Odd Notion (Fall 2009)',
#  'St. Bernardus Abt 12',
#  'Storm King Stout',
#  'Weihenstephaner Hefeweissbier Dunkel',
#  'Weihenstephaner Hefeweissbier',
#  'Ayinger Celebrator Doppelbock',
#  'Weihenstephaner Hefeweissbier',
#  'Founders Porter',
#  'Imperial Stout',
#  'XS Imperial India Pale Ale',
#  "Samuel Smith's, The Famous Taddy Porter",
#  'Stone 12th Anniversary Bitter Chocolate Oatmeal Stout',
#  'Smuttynose Imperial Stout (Big Beer Series)',
#  'Old Rasputin Russian Imperial Stout',
#  'Fred',
#  'Olde GnarlyWine',
#  'Saturnalia',
#  'Portsmouth Kate The Great',
#  'Founders Breakfast Stout',
#  'Weihenstephaner Hefeweissbier',
#  'Trappist Westvleteren 12',
#  'Trappist Westvleteren 8',
#  'Weihenstephaner Hefeweissbier',
#  'Portsmouth Kate The Great',
#  'Tröegs Nugget Nectar',
#  'Black Albert',
#  'Weihenstephaner Hefeweissbier',
#  'Schneider Aventinus',
#  'Weihenstephaner Hefeweissbier',
#  'Pullman Brown Ale',
#  'Sunspot',
#  'Moloko',
#  'Weihenstephaner Hefeweissbier',
#  'Bourbon County Brand Coffee Stout',
#  'Knuckle Sandwich',
#  'Weihenstephaner Hefeweissbier',
#  'Lunch',
#  'Weihenstephaner Hefeweissbier',
#  'Stone Imperial Russian Stout',
#  'Weihenstephaner Hefeweissbier',
#  "Bligh's Barleywine Ale",
#  'Pliny The Younger',
#  'The Wanderer',
#  'Just Outstanding IPA',
#  'Abrasive Ale',
#  'Toronado 20th Anniversary Ale',
#  'Dreadnaught IPA',
#  "Samuel Smith's, The Famous Taddy Porter",
#  'Founders CBS Imperial Stout',
#  "Bell's Hopslam Ale",
#  'La Fin Du Monde',
#  'Flower Power India Pale Ale',
#  'Insanity',
#  'Weihenstephaner Hefeweissbier',
#  'Old Rasputin Russian Imperial Stout',
#  'Storm King Stout',
#  'Founders Imperial Stout',
#  'Choklat',
#  'Stone Ruination IPA',
#  'Stone IPA (India Pale Ale)',
#  'Big Black Voodoo Daddy',
#  'Ten FIDY',
#  'Schlafly Christmas Ale',
#  'Damnation',
#  'Green Flash West Coast I.P.A.',
#  'Weihenstephaner Hefeweissbier',
#  "Samuel Smith's, The Famous Taddy Porter",
#  'Duvel',
#  'Allagash Tripel Ale',
#  'Weihenstephaner Hefeweissbier',
#  'Pliny The Younger',
#  'Imperial Eclipse Stout - Pappy Van Winkle',
#  'Duck-Rabbit Milk Stout',
#  "Bell's Special Double Cream Stout",
#  'Heady Topper',
#  'Portsmouth Kate The Great',
#  'Rare Bourbon County Stout',
#  'Founders KBS (Kentucky Breakfast Stout)',
#  "Hunahpu's Imperial Stout",
#  'Cantillon Blåbær Lambik',
#  'Sculpin India Pale Ale',
#  'Pliny The Elder',
#  'Pliny The Younger',
#  'Pliny The Elder',
#  'Weihenstephaner Hefeweissbier',
#  'Augustiner Bräu Lagerbier Hell',
#  'La Fin Du Monde',
#  'Green Flash West Coast I.P.A.',
#  'Tricerahops Double IPA',
#  'Weihenstephaner Hefeweissbier',
#  'Black Magick',
#  'Great Lakes Barrel-Aged Blackout Stout',
#  'Pliny The Younger',
#  'Flower Power India Pale Ale',
#  'Furious',
#  'Double Bastard Ale',
#  'My Antonia',
#  'Trappist Westvleteren 12',
#  'Trappistes Rochefort 8',
#  'Trappistes Rochefort 10',
#  "Armand'4 Oude Geuze Zomer (Summer)",
#  'Daisy Cutter Pale Ale',
#  'Daisy Cutter Pale Ale',
#  'The Abyss',
#  'Weihenstephaner Hefeweissbier',
#  'LeBleu',
#  'Mother Of All Storms',
#  'La Fin Du Monde',
#  'Old Stock Ale',
#  'Founders CBS Imperial Stout',
#  'Trappist Westvleteren 12',
#  'Weihenstephaner Vitus',
#  'Weihenstephaner Hefeweissbier',
#  'Tripel Karmeliet',
#  'Schneider Wiesen Edel-Weisse Mein Grunes',
#  'Ayinger Weizenbock',
#  'Gouden Carolus Tripel',
#  'Cantillon Blåbær Lambik',
#  'Dirty Horse',
#  'Stone Imperial Russian Stout',
#  'Pliny The Elder',
#  'Anchor Steam Beer',
#  'Trappistes Rochefort 10',
#  'Cuvee Delphine',
#  'Trappist Westvleteren 12',
#  'Trappist Westvleteren 8',
#  'Cuvée Van De Keizer Blauw (Blue)',
#  'Just Outstanding IPA',
#  'Citra DIPA',
#  'Sculpin India Pale Ale',
#  'Sculpin India Pale Ale',
#  'Furious',
#  'J.W. Lees Harvest Ale (Port Cask)',
#  'Weihenstephaner Hefeweissbier',
#  'Rare Bourbon County Stout',
#  'Weihenstephaner Hefeweissbier',
#  ...]
